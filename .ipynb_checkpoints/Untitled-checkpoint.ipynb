# %%
import pandas as pd

# %%
data_df = pd.read_csv('cities.csv')

# %%
data_df.to_html(index=False)
# Out:
#      City_ID                       City  Cloudiness Country        Date  \
# 0          0               longyearbyen          75      SJ  1483588200
# 1          1                       asau           0      RO  1483592400
# 2          2                  hartselle           1      US  1483592280
# 3          3               komsomolskiy          40      UZ  1483592400
# 4          4                      kapaa          90      US  1483592160
# 5          5                  cape town          36      ZA  1483593935
# 6          6                      damme           0      DE  1483591800
# 7          7                  taolanaro          75      MG  1483592400
# 8          8                 georgetown          75      GY  1483588800
# 9          9                    rikitea           0      PF  1483594241
# 10        10                     karaul           0      IN  1483594287
# 11        11               punta arenas           0      CL  1483588800
# ...
